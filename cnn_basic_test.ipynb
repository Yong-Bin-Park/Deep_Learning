# %%
# %run cnn_basic_model.ipynb
# %run dataset_flowers.ipynb
# %run dataset_office31.ipynb
# %run dataset_adam_animalface.ipynb

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])
aad = Adam_animalfaceDataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnBasicModel('flowers_model_1', fd, [30, 10])
fm1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.470, accuracy=0.323/0.340 (49/49 secs)
#     Epoch 4: cost=1.440, accuracy=0.334/0.290 (48/97 secs)
#     Epoch 6: cost=1.475, accuracy=0.308/0.210 (44/141 secs)
#     Epoch 8: cost=1.369, accuracy=0.385/0.270 (43/184 secs)
#     Epoch 10: cost=1.364, accuracy=0.399/0.330 (42/226 secs)
# Model flowers_model_1 train ended in 226 secs:
# Model flowers_model_1 test report: accuracy = 0.363, (1 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [30,40,14, 4,13] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [12,20,20,20,28] => 추정 tulip : 정답 sunflower => X
# 추정확률분포 [ 1, 1,56, 0,42] => 추정 rose : 정답 tulip => X

# %%
fm2 = CnnBasicModel('flowers_model_2', fd, 
                    [['full', {'width':30}], 
                     ['full', {'width':10}]])
fm2.use_adam = False
fm2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.599, accuracy=0.260/0.280 (11/11 secs)
#     Epoch 4: cost=1.497, accuracy=0.343/0.270 (12/23 secs)
#     Epoch 6: cost=1.358, accuracy=0.395/0.330 (11/34 secs)
#     Epoch 8: cost=1.295, accuracy=0.423/0.430 (11/45 secs)
#     Epoch 10: cost=1.239, accuracy=0.461/0.360 (12/57 secs)
# Model flowers_model_2 train ended in 57 secs:
# Model flowers_model_2 test report: accuracy = 0.396, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [ 0, 0,68, 0,31] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 8,23,14,30,25] => 추정 sunflower : 정답 dandelion => X
# 추정확률분포 [18,16,29,11,27] => 추정 rose : 정답 sunflower => X

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['avg', {'stride':2}]], 
               True)
fm3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_3 train started:
#     Epoch 2: cost=1.206, accuracy=0.518/0.530 (288/288 secs)
#     Epoch 4: cost=0.928, accuracy=0.646/0.560 (291/579 secs)
#     Epoch 6: cost=0.784, accuracy=0.695/0.650 (295/874 secs)
#     Epoch 8: cost=0.626, accuracy=0.766/0.560 (285/1159 secs)
#     Epoch 10: cost=0.517, accuracy=0.807/0.570 (285/1444 secs)
# Model flowers_model_3 train ended in 1444 secs:
# Model flowers_model_3 test report: accuracy = 0.554, (158 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [ 6, 4, 2, 0,88] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 7,49, 2,19,23] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 4, 1,80, 3,11] => 추정 rose : 정답 daisy => X

# %%
fm4 = CnnBasicModel('flowers_model_4', fd, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
fm4.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_4 train started:
#     Epoch 2: cost=1.143, accuracy=0.557/0.520 (329/329 secs)
#     Epoch 4: cost=0.895, accuracy=0.663/0.590 (275/604 secs)
#     Epoch 6: cost=0.757, accuracy=0.714/0.630 (257/861 secs)
#     Epoch 8: cost=0.664, accuracy=0.752/0.570 (248/1109 secs)
#     Epoch 10: cost=0.554, accuracy=0.794/0.730 (271/1380 secs)
# Model flowers_model_4 train ended in 1380 secs:
# Model flowers_model_4 test report: accuracy = 0.661, (31 secs)
#
# Model flowers_model_4 Visualization
# 추정확률분포 [ 4,58,22, 2,14] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 0,13,18,16,53] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 1, 0,98, 0, 0] => 추정 rose : 정답 tulip => X

# %%
om1 = CnnBasicModel('office31_model_1', od, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
om1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_1 train started:
#     Epoch 2: cost=2.695, accuracy=0.827+0.390/0.830+0.370 (244/244 secs)
#     Epoch 4: cost=1.629, accuracy=0.893+0.624/0.840+0.480 (263/507 secs)
#     Epoch 6: cost=0.941, accuracy=0.935+0.784/0.880+0.570 (252/759 secs)
#     Epoch 8: cost=0.574, accuracy=0.942+0.870/0.860+0.490 (253/1012 secs)
#     Epoch 10: cost=0.319, accuracy=0.970+0.933/0.840+0.530 (217/1229 secs)
# Model office31_model_1 train ended in 1229 secs:
# Model office31_model_1 test report: accuracy = 0.875+0.539, (21 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [61, 1,38] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 0, 0,...] => 추정 pen : 정답 scissors => X
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 0, 0,...] => 추정 laptop_computer : 정답 phone => X
# 추정확률분포 [ 0, 0, 0, 1, 0, 0, 0, 0,...] => 추정 monitor : 정답 paper_notebook => X

# %%
om1.exec_all(epoch_count = 40, show_cnt = 0)
# Out:
# Model office31_model_1 train ended in 4611 secs:
# Model office31_model_1 test report: accuracy = 0.896+0.523, (25 secs)

# %%
om2 = CnnBasicModel('office31_model_2', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'sigmoid'}], 
                ['avg', {'stride':3}]])
om2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_2 train started:
#     Epoch 2: cost=4.268, accuracy=0.686+0.031/0.700+0.010 (274/274 secs)
#     Epoch 4: cost=4.259, accuracy=0.686+0.037/0.610+0.010 (253/527 secs)
#     Epoch 6: cost=4.261, accuracy=0.686+0.035/0.620+0.010 (246/773 secs)
#     Epoch 8: cost=4.258, accuracy=0.686+0.035/0.670+0.020 (243/1016 secs)
#     Epoch 10: cost=4.258, accuracy=0.686+0.038/0.620+0.030 (241/1257 secs)
# Model office31_model_2 train ended in 1257 secs:
# Model office31_model_2 test report: accuracy = 0.693+0.040, (35 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 dslr => X
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [71,11,18] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 mouse => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 tape_dispenser => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 desk_chair => X

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}]])
om3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_3 train started:
#     Epoch 2: cost=3.619, accuracy=0.708+0.222/0.670+0.080 (268/268 secs)
#     Epoch 4: cost=3.579, accuracy=0.705+0.233/0.610+0.270 (255/523 secs)
#     Epoch 6: cost=2.946, accuracy=0.756+0.387/0.750+0.350 (252/775 secs)
#     Epoch 8: cost=3.130, accuracy=0.726+0.331/0.670+0.310 (253/1028 secs)
#     Epoch 10: cost=2.646, accuracy=0.786+0.445/0.740+0.280 (255/1283 secs)
# Model office31_model_3 train ended in 1283 secs:
# Model office31_model_3 test report: accuracy = 0.749+0.336, (18 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [60,13,27] => 추정 amazon : 정답 webcam => X
# 추정확률분포 [75, 4,21] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [96, 1, 3] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 0, 0, 0, 2, 1, 2, 0,...] => 추정 stapler : 정답 keyboard => X
# 추정확률분포 [ 0, 1, 2, 2, 0, 0,11, 3,...] => 추정 file_cabinet : 정답 speaker => X
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 0, 0,...] => 추정 letter_tray : 정답 letter_tray => O
